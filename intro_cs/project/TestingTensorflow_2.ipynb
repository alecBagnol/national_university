# %% [markdown]
# <h2>Building an Artificial Neural Network (ANN)</h2>
# <p>A supervised learning system built of a large number of simple elements , called neurons or perceptrons. Each neuron can make simple decisions, and feeds those decisions to other neurons, organized in interconnected layers.</p>
# <h2>But... whats an Activation Function?</h2>
# It sort of gives the inputs a function to get the output.. it defines the output of a neural network; they can be linear or non-linear.

# %%
import tensorflow as tf
from tensorflow import keras

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
